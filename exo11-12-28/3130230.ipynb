# %%
import pandas as pd
import matplotlib.pyplot as plt

paxes = ['Pax0.csv', 'Pax1.csv', 'Pax2.csv', 'Pax3.csv', 'Pax4.csv', 'Pax5.csv', 'Pax6.csv', 'Pax7.csv']


for pax in range(len(paxes)):
    df_pax = pd.read_csv(paxes[pax])
    DateOfDeparture = df_pax['DateOfDeparture'].str.split('-')
    weeksToDeparture = df_pax['WeeksToDeparture']
    std_wtd = df_pax['std_wtd']
    plt.hist(weeksToDeparture, bins = 25)
    plt.savefig('weeksToDeparture'+str(pax)+'.png')
    plt.show()
    plt.hist(std_wtd, bins = 25)
    plt.savefig('std_wtd'+str(pax)+'.png')
    plt.show()

'''
year = []
month = []
day = []
for item in DateOfDeparture:
    year.append(int(item[0]))
    month.append(int(item[1]))
    day.append(int(item[2]))


plt.hist(year, bins=6)
plt.show()
plt.hist(month, bins=24)
plt.show()
plt.hist(day, bins=62)
plt.show()

#cat = ["bored", "happy", "bored", "bored", "happy", "bored"]
# dog = ["happy", "happy", "happy", "happy", "bored", "bored"]
# activity = ["combing", "drinking", "feeding", "napping", "playing", "washing"]

# fig, ax = plt.subplots()
# ax.plot(activity, dog, label="dog")
# ax.plot(activity, cat, label="cat")
# ax.legend()
#
#
'''
# Out:
# '\nyear = []\nmonth = []\nday = []\nfor item in DateOfDeparture:\n    year.append(int(item[0]))\n    month.append(int(item[1]))\n    day.append(int(item[2]))\n\n\nplt.hist(year, bins=6)\nplt.show()\nplt.hist(month, bins=24)\nplt.show()\nplt.hist(day, bins=62)\nplt.show()\n\n#cat = ["bored", "happy", "bored", "bored", "happy", "bored"]\n# dog = ["happy", "happy", "happy", "happy", "bored", "bored"]\n# activity = ["combing", "drinking", "feeding", "napping", "playing", "washing"]\n\n# fig, ax = plt.subplots()\n# ax.plot(activity, dog, label="dog")\n# ax.plot(activity, cat, label="cat")\n# ax.legend()\n#\n#\n'
